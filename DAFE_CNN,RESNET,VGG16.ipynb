# %% [markdown]
# <a href="https://colab.research.google.com/github/dheeraj0000/DAFE-PROJECT-RESEARCH-PAPER/blob/main/DAFE_CNN%2CRESNET%2CVGG16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Mount Google Drive to access the dataset
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Load libraries
import numpy as np
import keras
from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Activation
#from keras.layers.core import Flatten, Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
#from keras.layers.normalization import BatchNormalization
#from keras.layers.convolutional import *
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools
from keras.preprocessing.image import ImageDataGenerator
from keras import applications
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D
from keras import optimizers
from sklearn.preprocessing import LabelEncoder
#from keras.utils import np_utils
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
datagen = ImageDataGenerator(rescale=1./255)
train_path = '/content/drive/MyDrive/MONKEYPOX Disease/Fold1/Fold1/Fold1/Train'

train_batches = ImageDataGenerator().flow_from_directory(train_path, target_size=(115,115),
                                                         classes=['Monkeypox','Non Monkeypox'], class_mode='categorical',
                                                         batch_size=27560)

imgs, label = next(train_batches)
print(label.shape)
print(imgs.shape)
# Out:
# Found 980 images belonging to 2 classes.
# (980, 2)
# (980, 115, 115, 3)

# %%
# We need to separate the data into train and test arrays
X_train, X_test, y_train, y_test = train_test_split(imgs,label,test_size=0.3,random_state=42)

# %%
datagen = ImageDataGenerator(
        rotation_range=10,  # Rotate images randomly
        zoom_range = 0.1, # Zoom images randomly
        width_shift_range=0.1,  # Horizontally shift images in random order
        height_shift_range=0.1  # Vertically shift images in random order
)

datagen.fit(X_train)

# %%
for i in range (0,5):
    image = imgs[i]
    plt.imshow((image * 255).astype(np.uint8))
    if (label[i][0]==1):
      print("Monkeypox")
    if (label[i][1]==1):
        print("Non Monkeypox")
    plt.show()
# Out:
# Monkeypox
# Monkeypox
# Monkeypox
# Monkeypox
# Monkeypox

# %%
def show_confusion_matrix(history, model, x_test, y_test):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Predict class probabilities
    predicted_probabilities = model.predict(x_test)

    # Determine the class with the highest probability for each sample
    predicted_classes = np.argmax(predicted_probabilities, axis=1)

    # Rest of your code for the confusion matrix
    cm1 = confusion_matrix(np.argmax(y_test, axis=1), predicted_classes)
    print('Confusion Matrix : \n')
    print(cm1)

# %% [markdown]
# VGG16 Model - All Layers Frozen

# %%
# model1 freeze all layers
# VGG16 pre-trained model
image_w, image_h = 115, 115
model1 = applications.VGG16(weights = "imagenet", include_top=False, input_shape = (image_w, image_h, 3))
model1.summary()

# Freezing all the layers
for layer in model1.layers[:]:
    layer.trainable = False

# Trainable layers
print("Trainable Layers:")
for i, layer in enumerate(model1.layers):
    print(i, layer.name, layer.trainable)

# Adding custom layers to create a new model
new_model = Sequential([
    model1,
    Flatten(name='flatten'),
    Dense(256, activation='relu', name='new_fc1'),
    Dropout(0.5),
    Dense(2, activation='softmax', name='new_predictions')
])
new_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 115, 115, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 115, 115, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 115, 115, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 57, 57, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 57, 57, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 57, 57, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 28, 28, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 28, 28, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 28, 28, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 14, 14, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 14, 14, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 7, 7, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Trainable Layers:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 False
# 16 block5_conv2 False
# 17 block5_conv3 False
# 18 block5_pool False
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 3, 3, 512)         14714688
#
#  flatten (Flatten)           (None, 4608)              0
#
#  new_fc1 (Dense)             (None, 256)               1179904
#
#  dropout (Dropout)           (None, 256)               0
#
#  new_predictions (Dense)     (None, 2)                 514
#
# =================================================================
# Total params: 15895106 (60.64 MB)
# Trainable params: 1180418 (4.50 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
# Compiling the model - SGD Optimizer
new_model.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy"])

#Fitting the model on the train data and labels.
print("Batch Size: 10, Epoch: 5, Optimizer: SGD")
new_model.fit(imgs, label, batch_size=10, epochs=5, verbose=1, validation_split=0.30, shuffle=True)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Batch Size: 10, Epoch: 5, Optimizer: SGD
# Epoch 1/5
# 69/69 [==============================] - 198s 3s/step - loss: 0.1990 - accuracy: 0.9898 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/5
# 69/69 [==============================] - 190s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/5
# 69/69 [==============================] - 192s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/5
# 69/69 [==============================] - 193s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/5
# 69/69 [==============================] - 190s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %%
# Compiling the model - Adam Optimizer
new_model.compile(loss = "categorical_crossentropy", optimizer = optimizers.Adam(lr=0.0001), metrics=["accuracy"])
#Fitting the model on the train data and labels.
print("Batch Size: 10, Epoch: 5, Optimizer: Adam")
new_model.fit(imgs, label, batch_size=10, epochs=5, verbose=1, validation_split=0.30, shuffle=True)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Batch Size: 10, Epoch: 5, Optimizer: Adam
# Epoch 1/5
# 69/69 [==============================] - 190s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/5
# 69/69 [==============================] - 191s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/5
# 69/69 [==============================] - 189s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/5
# 69/69 [==============================] - 189s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/5
# 69/69 [==============================] - 189s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %% [markdown]
# VGG16 Model - Unfreeze Last Layer

# %%
#Model2 unfreeze last layer
# VGG16 pre-trained model without fully connected layers and with different input dimensions
image_w, image_h = 115, 115
model2 = applications.VGG16(weights = "imagenet", include_top=False, input_shape = (image_w, image_h, 3))
#model2.summary()

# Freezing the layers except the last one
for i, layer in enumerate(model2.layers):
  layer.trainable = False
  if (i >=15 ):
    layer.trainable = True

for i, layer in enumerate(model2.layers):
    print(i, layer.name, layer.trainable)

# Adding custom layers to create a new model
new_model2 = Sequential([
    model2,
    Flatten(name='flatten'),
    Dense(512, activation='relu', name='new_fc1'),
    Dropout(0.5),
    Dense(2, activation='softmax', name='new_predictions')
])
# Out:
# 0 input_2 False
# 1 block1_conv1 False
# 2 block1_conv2 False
# 3 block1_pool False
# 4 block2_conv1 False
# 5 block2_conv2 False
# 6 block2_pool False
# 7 block3_conv1 False
# 8 block3_conv2 False
# 9 block3_conv3 False
# 10 block3_pool False
# 11 block4_conv1 False
# 12 block4_conv2 False
# 13 block4_conv3 False
# 14 block4_pool False
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
# Compiling the model - SGD Optimizer
new_model2.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.00001, momentum=0.9), metrics=["accuracy"])

#Fitting the model on the train data and labels.
print("Batch Size: 10, Epoch: 5, Optimizer: SGD")
new_model2.fit(imgs, label, batch_size=10, epochs=5, verbose=1, validation_split=0.30, shuffle=True)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Batch Size: 10, Epoch: 5, Optimizer: SGD
# Epoch 1/5
# 69/69 [==============================] - 217s 3s/step - loss: 0.1741 - accuracy: 0.9883 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/5
# 69/69 [==============================] - 215s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/5
# 69/69 [==============================] - 213s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/5
# 69/69 [==============================] - 216s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/5
# 69/69 [==============================] - 216s 3s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %% [markdown]
# VGG16 Model - All Layers Trainable

# %%
#Model2 unfreeze last layer
# VGG16 pre-trained model without fully connected layers and with different input dimensions
image_w, image_h = 115, 115
model2 = applications.VGG16(weights = "imagenet", include_top=False, input_shape = (image_w, image_h, 3))
#model2.summary()

# Freezing the layers except the last one
for i, layer in enumerate(model2.layers):
  layer.trainable = True

for i, layer in enumerate(model2.layers):
    print(i, layer.name, layer.trainable)

# Adding custom layers to create a new model
new_model2 = Sequential([
    model2,
    Flatten(name='flatten'),
    Dense(512, activation='relu', name='new_fc1'),
    Dropout(0.5),
    Dense(2, activation='softmax', name='new_predictions')
])
# Out:
# 0 input_4 True
# 1 block1_conv1 True
# 2 block1_conv2 True
# 3 block1_pool True
# 4 block2_conv1 True
# 5 block2_conv2 True
# 6 block2_pool True
# 7 block3_conv1 True
# 8 block3_conv2 True
# 9 block3_conv3 True
# 10 block3_pool True
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool True
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
# Compiling the model - Adam Optimizer
new_model2.compile(loss = "categorical_crossentropy", optimizer = optimizers.Adam(lr=0.00001), metrics=["accuracy"])

#Fitting the model on the train data and labels.
print("Batch Size: 10, Epoch: 5, Optimizer: Adam")
new_model2.fit(imgs, label, batch_size=10, epochs=5, verbose=1, validation_split=0.30, shuffle=True)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Batch Size: 10, Epoch: 5, Optimizer: Adam
# Epoch 1/5
# 69/69 [==============================] - 495s 7s/step - loss: 0.1776 - accuracy: 0.9883 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/5
# 69/69 [==============================] - 487s 7s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/5
# 69/69 [==============================] - 475s 7s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/5
# 69/69 [==============================] - 476s 7s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/5
# 69/69 [==============================] - 473s 7s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %% [markdown]
# ResNet 50 Model - All Layers Trainable

# %%
image_w, image_h = 115, 115
model = keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=(image_w, image_h, 3))

model.summary()
    # Adding custom layers to create a new model
new_model2 = Sequential([
    model,
    Flatten(name='flatten'),
    Dense(512, activation='relu', name='new_fc1'),
    Dropout(0.5),
    Dense(2, activation='softmax', name='new_predictions')
])
#new_model2.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 115, 115, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 121, 121, 3)          0         ['input_3[0][0]']
#
#  conv1_conv (Conv2D)         (None, 58, 58, 64)           9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 58, 58, 64)           256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 58, 58, 64)           0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 60, 60, 64)           0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 29, 29, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 29, 29, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 29, 29, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 29, 29, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 29, 29, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 29, 29, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 29, 29, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 29, 29, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 29, 29, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 29, 29, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 29, 29, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 29, 29, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 29, 29, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 29, 29, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 29, 29, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 29, 29, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 29, 29, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 29, 29, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 29, 29, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 29, 29, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 29, 29, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 29, 29, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 29, 29, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 29, 29, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 29, 29, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 29, 29, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 29, 29, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 29, 29, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 29, 29, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 29, 29, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 29, 29, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 29, 29, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 29, 29, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 15, 15, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 15, 15, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 15, 15, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 15, 15, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 15, 15, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 15, 15, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 15, 15, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 15, 15, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 15, 15, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 15, 15, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 15, 15, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 15, 15, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 15, 15, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 15, 15, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 15, 15, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 15, 15, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 15, 15, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 15, 15, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 15, 15, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 15, 15, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 15, 15, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 15, 15, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 15, 15, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 15, 15, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 15, 15, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 15, 15, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 15, 15, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 15, 15, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 15, 15, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 15, 15, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 15, 15, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 15, 15, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 15, 15, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 15, 15, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 15, 15, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 15, 15, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 15, 15, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 15, 15, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 15, 15, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 15, 15, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 15, 15, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 15, 15, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 8, 8, 256)            131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 8, 8, 256)            590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 8, 8, 1024)           525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 8, 8, 1024)           263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 8, 8, 1024)           4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 8, 8, 1024)           4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 8, 8, 1024)           0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 8, 8, 1024)           0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 8, 8, 256)            262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 8, 8, 256)            590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 8, 8, 1024)           263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 8, 8, 1024)           4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 8, 8, 1024)           0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 8, 8, 1024)           0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 8, 8, 256)            262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 8, 8, 256)            590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 8, 8, 1024)           263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 8, 8, 1024)           4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 8, 8, 1024)           0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 8, 8, 1024)           0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 8, 8, 256)            262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 8, 8, 256)            590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 8, 8, 1024)           263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 8, 8, 1024)           4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 8, 8, 1024)           0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 8, 8, 1024)           0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 8, 8, 256)            262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 8, 8, 256)            590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 8, 8, 1024)           263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 8, 8, 1024)           4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 8, 8, 1024)           0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 8, 8, 1024)           0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 8, 8, 256)            262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 8, 8, 256)            590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 8, 8, 256)            1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 8, 8, 256)            0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 8, 8, 1024)           263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 8, 8, 1024)           4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 8, 8, 1024)           0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 8, 8, 1024)           0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 4, 4, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 4, 4, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 4, 4, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 4, 4, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 4, 4, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 4, 4, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 4, 4, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 4, 4, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 4, 4, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 4, 4, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 4, 4, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 4, 4, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 4, 4, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 4, 4, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 4, 4, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 4, 4, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 4, 4, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 4, 4, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 4, 4, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 4, 4, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 4, 4, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 4, 4, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 4, 4, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 4, 4, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 4, 4, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 4, 4, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 4, 4, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 4, 4, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 4, 4, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 4, 4, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 4, 4, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 4, 4, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 23587712 (89.98 MB)
# Trainable params: 23534592 (89.78 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
# Compiling the model - Adam Optimizer
new_model2.compile(loss = "categorical_crossentropy", optimizer = optimizers.Adam(lr=0.00001), metrics=["accuracy"])
es = keras.callbacks.EarlyStopping(monitor='val_acc', verbose=1, mode='max', patience=2)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
# Fitting the model on the train data and labels.
batch_size = 100
history = new_model2.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), epochs=5, validation_data=(X_test, y_test), verbose=1, steps_per_epoch=X_train.shape[0] // batch_size, callbacks=[es])

print("Batch Size: 20, Epoch: 5, Optimizer: Adam")

show_confusion_matrix(history, new_model2, X_test, y_test)
# Out:
# <ipython-input-15-084859ab2861>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = new_model2.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), epochs=5, validation_data=(X_test, y_test), verbose=1, steps_per_epoch=X_train.shape[0] // batch_size, callbacks=[es])
# Epoch 1/5
# 6/6 [==============================] - ETA: 0s - loss: 0.3045 - accuracy: 0.9147
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 209s 31s/step - loss: 0.3045 - accuracy: 0.9147 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 180s 30s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 184s 31s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 199s 34s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 181s 31s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Batch Size: 20, Epoch: 5, Optimizer: Adam
# 10/10 [==============================] - 17s 2s/step
# Confusion Matrix :
#
# [[294]]

# %% [markdown]
# Densenet 121 - All Layers Trainable

# %%
image_w, image_h = 115, 115
model = keras.applications.DenseNet121(include_top=False, weights='imagenet', input_shape=(image_w, image_h, 3))

for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
model.summary()
    # Adding custom layers to create a new model
new_model2 = Sequential([
    model,
    Flatten(name='flatten'),
    Dense(512, activation='relu', name='new_fc1'),
    Dropout(0.5),
    Dense(2, activation='softmax', name='new_predictions')
])
#new_model2.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# 0 input_5 True
# 1 zero_padding2d True
# 2 conv1/conv True
# 3 conv1/bn True
# 4 conv1/relu True
# 5 zero_padding2d_1 True
# 6 pool1 True
# 7 conv2_block1_0_bn True
# 8 conv2_block1_0_relu True
# 9 conv2_block1_1_conv True
# 10 conv2_block1_1_bn True
# 11 conv2_block1_1_relu True
# 12 conv2_block1_2_conv True
# 13 conv2_block1_concat True
# 14 conv2_block2_0_bn True
# 15 conv2_block2_0_relu True
# 16 conv2_block2_1_conv True
# 17 conv2_block2_1_bn True
# 18 conv2_block2_1_relu True
# 19 conv2_block2_2_conv True
# 20 conv2_block2_concat True
# 21 conv2_block3_0_bn True
# 22 conv2_block3_0_relu True
# 23 conv2_block3_1_conv True
# 24 conv2_block3_1_bn True
# 25 conv2_block3_1_relu True
# 26 conv2_block3_2_conv True
# 27 conv2_block3_concat True
# 28 conv2_block4_0_bn True
# 29 conv2_block4_0_relu True
# 30 conv2_block4_1_conv True
# 31 conv2_block4_1_bn True
# 32 conv2_block4_1_relu True
# 33 conv2_block4_2_conv True
# 34 conv2_block4_concat True
# 35 conv2_block5_0_bn True
# 36 conv2_block5_0_relu True
# 37 conv2_block5_1_conv True
# 38 conv2_block5_1_bn True
# 39 conv2_block5_1_relu True
# 40 conv2_block5_2_conv True
# 41 conv2_block5_concat True
# 42 conv2_block6_0_bn True
# 43 conv2_block6_0_relu True
# 44 conv2_block6_1_conv True
# 45 conv2_block6_1_bn True
# 46 conv2_block6_1_relu True
# 47 conv2_block6_2_conv True
# 48 conv2_block6_concat True
# 49 pool2_bn True
# 50 pool2_relu True
# 51 pool2_conv True
# 52 pool2_pool True
# 53 conv3_block1_0_bn True
# 54 conv3_block1_0_relu True
# 55 conv3_block1_1_conv True
# 56 conv3_block1_1_bn True
# 57 conv3_block1_1_relu True
# 58 conv3_block1_2_conv True
# 59 conv3_block1_concat True
# 60 conv3_block2_0_bn True
# 61 conv3_block2_0_relu True
# 62 conv3_block2_1_conv True
# 63 conv3_block2_1_bn True
# 64 conv3_block2_1_relu True
# 65 conv3_block2_2_conv True
# 66 conv3_block2_concat True
# 67 conv3_block3_0_bn True
# 68 conv3_block3_0_relu True
# 69 conv3_block3_1_conv True
# 70 conv3_block3_1_bn True
# 71 conv3_block3_1_relu True
# 72 conv3_block3_2_conv True
# 73 conv3_block3_concat True
# 74 conv3_block4_0_bn True
# 75 conv3_block4_0_relu True
# 76 conv3_block4_1_conv True
# 77 conv3_block4_1_bn True
# 78 conv3_block4_1_relu True
# 79 conv3_block4_2_conv True
# 80 conv3_block4_concat True
# 81 conv3_block5_0_bn True
# 82 conv3_block5_0_relu True
# 83 conv3_block5_1_conv True
# 84 conv3_block5_1_bn True
# 85 conv3_block5_1_relu True
# 86 conv3_block5_2_conv True
# 87 conv3_block5_concat True
# 88 conv3_block6_0_bn True
# 89 conv3_block6_0_relu True
# 90 conv3_block6_1_conv True
# 91 conv3_block6_1_bn True
# 92 conv3_block6_1_relu True
# 93 conv3_block6_2_conv True
# 94 conv3_block6_concat True
# 95 conv3_block7_0_bn True
# 96 conv3_block7_0_relu True
# 97 conv3_block7_1_conv True
# 98 conv3_block7_1_bn True
# 99 conv3_block7_1_relu True
# 100 conv3_block7_2_conv True
# 101 conv3_block7_concat True
# 102 conv3_block8_0_bn True
# 103 conv3_block8_0_relu True
# 104 conv3_block8_1_conv True
# 105 conv3_block8_1_bn True
# 106 conv3_block8_1_relu True
# 107 conv3_block8_2_conv True
# 108 conv3_block8_concat True
# 109 conv3_block9_0_bn True
# 110 conv3_block9_0_relu True
# 111 conv3_block9_1_conv True
# 112 conv3_block9_1_bn True
# 113 conv3_block9_1_relu True
# 114 conv3_block9_2_conv True
# 115 conv3_block9_concat True
# 116 conv3_block10_0_bn True
# 117 conv3_block10_0_relu True
# 118 conv3_block10_1_conv True
# 119 conv3_block10_1_bn True
# 120 conv3_block10_1_relu True
# 121 conv3_block10_2_conv True
# 122 conv3_block10_concat True
# 123 conv3_block11_0_bn True
# 124 conv3_block11_0_relu True
# 125 conv3_block11_1_conv True
# 126 conv3_block11_1_bn True
# 127 conv3_block11_1_relu True
# 128 conv3_block11_2_conv True
# 129 conv3_block11_concat True
# 130 conv3_block12_0_bn True
# 131 conv3_block12_0_relu True
# 132 conv3_block12_1_conv True
# 133 conv3_block12_1_bn True
# 134 conv3_block12_1_relu True
# 135 conv3_block12_2_conv True
# 136 conv3_block12_concat True
# 137 pool3_bn True
# 138 pool3_relu True
# 139 pool3_conv True
# 140 pool3_pool True
# 141 conv4_block1_0_bn True
# 142 conv4_block1_0_relu True
# 143 conv4_block1_1_conv True
# 144 conv4_block1_1_bn True
# 145 conv4_block1_1_relu True
# 146 conv4_block1_2_conv True
# 147 conv4_block1_concat True
# 148 conv4_block2_0_bn True
# 149 conv4_block2_0_relu True
# 150 conv4_block2_1_conv True
# 151 conv4_block2_1_bn True
# 152 conv4_block2_1_relu True
# 153 conv4_block2_2_conv True
# 154 conv4_block2_concat True
# 155 conv4_block3_0_bn True
# 156 conv4_block3_0_relu True
# 157 conv4_block3_1_conv True
# 158 conv4_block3_1_bn True
# 159 conv4_block3_1_relu True
# 160 conv4_block3_2_conv True
# 161 conv4_block3_concat True
# 162 conv4_block4_0_bn True
# 163 conv4_block4_0_relu True
# 164 conv4_block4_1_conv True
# 165 conv4_block4_1_bn True
# 166 conv4_block4_1_relu True
# 167 conv4_block4_2_conv True
# 168 conv4_block4_concat True
# 169 conv4_block5_0_bn True
# 170 conv4_block5_0_relu True
# 171 conv4_block5_1_conv True
# 172 conv4_block5_1_bn True
# 173 conv4_block5_1_relu True
# 174 conv4_block5_2_conv True
# 175 conv4_block5_concat True
# 176 conv4_block6_0_bn True
# 177 conv4_block6_0_relu True
# 178 conv4_block6_1_conv True
# 179 conv4_block6_1_bn True
# 180 conv4_block6_1_relu True
# 181 conv4_block6_2_conv True
# 182 conv4_block6_concat True
# 183 conv4_block7_0_bn True
# 184 conv4_block7_0_relu True
# 185 conv4_block7_1_conv True
# 186 conv4_block7_1_bn True
# 187 conv4_block7_1_relu True
# 188 conv4_block7_2_conv True
# 189 conv4_block7_concat True
# 190 conv4_block8_0_bn True
# 191 conv4_block8_0_relu True
# 192 conv4_block8_1_conv True
# 193 conv4_block8_1_bn True
# 194 conv4_block8_1_relu True
# 195 conv4_block8_2_conv True
# 196 conv4_block8_concat True
# 197 conv4_block9_0_bn True
# 198 conv4_block9_0_relu True
# 199 conv4_block9_1_conv True
# 200 conv4_block9_1_bn True
# 201 conv4_block9_1_relu True
# 202 conv4_block9_2_conv True
# 203 conv4_block9_concat True
# 204 conv4_block10_0_bn True
# 205 conv4_block10_0_relu True
# 206 conv4_block10_1_conv True
# 207 conv4_block10_1_bn True
# 208 conv4_block10_1_relu True
# 209 conv4_block10_2_conv True
# 210 conv4_block10_concat True
# 211 conv4_block11_0_bn True
# 212 conv4_block11_0_relu True
# 213 conv4_block11_1_conv True
# 214 conv4_block11_1_bn True
# 215 conv4_block11_1_relu True
# 216 conv4_block11_2_conv True
# 217 conv4_block11_concat True
# 218 conv4_block12_0_bn True
# 219 conv4_block12_0_relu True
# 220 conv4_block12_1_conv True
# 221 conv4_block12_1_bn True
# 222 conv4_block12_1_relu True
# 223 conv4_block12_2_conv True
# 224 conv4_block12_concat True
# 225 conv4_block13_0_bn True
# 226 conv4_block13_0_relu True
# 227 conv4_block13_1_conv True
# 228 conv4_block13_1_bn True
# 229 conv4_block13_1_relu True
# 230 conv4_block13_2_conv True
# 231 conv4_block13_concat True
# 232 conv4_block14_0_bn True
# 233 conv4_block14_0_relu True
# 234 conv4_block14_1_conv True
# 235 conv4_block14_1_bn True
# 236 conv4_block14_1_relu True
# 237 conv4_block14_2_conv True
# 238 conv4_block14_concat True
# 239 conv4_block15_0_bn True
# 240 conv4_block15_0_relu True
# 241 conv4_block15_1_conv True
# 242 conv4_block15_1_bn True
# 243 conv4_block15_1_relu True
# 244 conv4_block15_2_conv True
# 245 conv4_block15_concat True
# 246 conv4_block16_0_bn True
# 247 conv4_block16_0_relu True
# 248 conv4_block16_1_conv True
# 249 conv4_block16_1_bn True
# 250 conv4_block16_1_relu True
# 251 conv4_block16_2_conv True
# 252 conv4_block16_concat True
# 253 conv4_block17_0_bn True
# 254 conv4_block17_0_relu True
# 255 conv4_block17_1_conv True
# 256 conv4_block17_1_bn True
# 257 conv4_block17_1_relu True
# 258 conv4_block17_2_conv True
# 259 conv4_block17_concat True
# 260 conv4_block18_0_bn True
# 261 conv4_block18_0_relu True
# 262 conv4_block18_1_conv True
# 263 conv4_block18_1_bn True
# 264 conv4_block18_1_relu True
# 265 conv4_block18_2_conv True
# 266 conv4_block18_concat True
# 267 conv4_block19_0_bn True
# 268 conv4_block19_0_relu True
# 269 conv4_block19_1_conv True
# 270 conv4_block19_1_bn True
# 271 conv4_block19_1_relu True
# 272 conv4_block19_2_conv True
# 273 conv4_block19_concat True
# 274 conv4_block20_0_bn True
# 275 conv4_block20_0_relu True
# 276 conv4_block20_1_conv True
# 277 conv4_block20_1_bn True
# 278 conv4_block20_1_relu True
# 279 conv4_block20_2_conv True
# 280 conv4_block20_concat True
# 281 conv4_block21_0_bn True
# 282 conv4_block21_0_relu True
# 283 conv4_block21_1_conv True
# 284 conv4_block21_1_bn True
# 285 conv4_block21_1_relu True
# 286 conv4_block21_2_conv True
# 287 conv4_block21_concat True
# 288 conv4_block22_0_bn True
# 289 conv4_block22_0_relu True
# 290 conv4_block22_1_conv True
# 291 conv4_block22_1_bn True
# 292 conv4_block22_1_relu True
# 293 conv4_block22_2_conv True
# 294 conv4_block22_concat True
# 295 conv4_block23_0_bn True
# 296 conv4_block23_0_relu True
# 297 conv4_block23_1_conv True
# 298 conv4_block23_1_bn True
# 299 conv4_block23_1_relu True
# 300 conv4_block23_2_conv True
# 301 conv4_block23_concat True
# 302 conv4_block24_0_bn True
# 303 conv4_block24_0_relu True
# 304 conv4_block24_1_conv True
# 305 conv4_block24_1_bn True
# 306 conv4_block24_1_relu True
# 307 conv4_block24_2_conv True
# 308 conv4_block24_concat True
# 309 pool4_bn True
# 310 pool4_relu True
# 311 pool4_conv True
# 312 pool4_pool True
# 313 conv5_block1_0_bn True
# 314 conv5_block1_0_relu True
# 315 conv5_block1_1_conv True
# 316 conv5_block1_1_bn True
# 317 conv5_block1_1_relu True
# 318 conv5_block1_2_conv True
# 319 conv5_block1_concat True
# 320 conv5_block2_0_bn True
# 321 conv5_block2_0_relu True
# 322 conv5_block2_1_conv True
# 323 conv5_block2_1_bn True
# 324 conv5_block2_1_relu True
# 325 conv5_block2_2_conv True
# 326 conv5_block2_concat True
# 327 conv5_block3_0_bn True
# 328 conv5_block3_0_relu True
# 329 conv5_block3_1_conv True
# 330 conv5_block3_1_bn True
# 331 conv5_block3_1_relu True
# 332 conv5_block3_2_conv True
# 333 conv5_block3_concat True
# 334 conv5_block4_0_bn True
# 335 conv5_block4_0_relu True
# 336 conv5_block4_1_conv True
# 337 conv5_block4_1_bn True
# 338 conv5_block4_1_relu True
# 339 conv5_block4_2_conv True
# 340 conv5_block4_concat True
# 341 conv5_block5_0_bn True
# 342 conv5_block5_0_relu True
# 343 conv5_block5_1_conv True
# 344 conv5_block5_1_bn True
# 345 conv5_block5_1_relu True
# 346 conv5_block5_2_conv True
# 347 conv5_block5_concat True
# 348 conv5_block6_0_bn True
# 349 conv5_block6_0_relu True
# 350 conv5_block6_1_conv True
# 351 conv5_block6_1_bn True
# 352 conv5_block6_1_relu True
# 353 conv5_block6_2_conv True
# 354 conv5_block6_concat True
# 355 conv5_block7_0_bn True
# 356 conv5_block7_0_relu True
# 357 conv5_block7_1_conv True
# 358 conv5_block7_1_bn True
# 359 conv5_block7_1_relu True
# 360 conv5_block7_2_conv True
# 361 conv5_block7_concat True
# 362 conv5_block8_0_bn True
# 363 conv5_block8_0_relu True
# 364 conv5_block8_1_conv True
# 365 conv5_block8_1_bn True
# 366 conv5_block8_1_relu True
# 367 conv5_block8_2_conv True
# 368 conv5_block8_concat True
# 369 conv5_block9_0_bn True
# 370 conv5_block9_0_relu True
# 371 conv5_block9_1_conv True
# 372 conv5_block9_1_bn True
# 373 conv5_block9_1_relu True
# 374 conv5_block9_2_conv True
# 375 conv5_block9_concat True
# 376 conv5_block10_0_bn True
# 377 conv5_block10_0_relu True
# 378 conv5_block10_1_conv True
# 379 conv5_block10_1_bn True
# 380 conv5_block10_1_relu True
# 381 conv5_block10_2_conv True
# 382 conv5_block10_concat True
# 383 conv5_block11_0_bn True
# 384 conv5_block11_0_relu True
# 385 conv5_block11_1_conv True
# 386 conv5_block11_1_bn True
# 387 conv5_block11_1_relu True
# 388 conv5_block11_2_conv True
# 389 conv5_block11_concat True
# 390 conv5_block12_0_bn True
# 391 conv5_block12_0_relu True
# 392 conv5_block12_1_conv True
# 393 conv5_block12_1_bn True
# 394 conv5_block12_1_relu True
# 395 conv5_block12_2_conv True
# 396 conv5_block12_concat True
# 397 conv5_block13_0_bn True
# 398 conv5_block13_0_relu True
# 399 conv5_block13_1_conv True
# 400 conv5_block13_1_bn True
# 401 conv5_block13_1_relu True
# 402 conv5_block13_2_conv True
# 403 conv5_block13_concat True
# 404 conv5_block14_0_bn True
# 405 conv5_block14_0_relu True
# 406 conv5_block14_1_conv True
# 407 conv5_block14_1_bn True
# 408 conv5_block14_1_relu True
# 409 conv5_block14_2_conv True
# 410 conv5_block14_concat True
# 411 conv5_block15_0_bn True
# 412 conv5_block15_0_relu True
# 413 conv5_block15_1_conv True
# 414 conv5_block15_1_bn True
# 415 conv5_block15_1_relu True
# 416 conv5_block15_2_conv True
# 417 conv5_block15_concat True
# 418 conv5_block16_0_bn True
# 419 conv5_block16_0_relu True
# 420 conv5_block16_1_conv True
# 421 conv5_block16_1_bn True
# 422 conv5_block16_1_relu True
# 423 conv5_block16_2_conv True
# 424 conv5_block16_concat True
# 425 bn True
# 426 relu True
# Model: "densenet121"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 115, 115, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 121, 121, 3)          0         ['input_5[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 58, 58, 64)           9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 58, 58, 64)           256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 58, 58, 64)           0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 60, 60, 64)           0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 29, 29, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 29, 29, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 29, 29, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 29, 29, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 29, 29, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 29, 29, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 29, 29, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 29, 29, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 29, 29, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 29, 29, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 29, 29, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 29, 29, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 29, 29, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 29, 29, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 29, 29, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 29, 29, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 29, 29, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 29, 29, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 29, 29, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 29, 29, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 29, 29, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 29, 29, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 29, 29, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 29, 29, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 29, 29, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 29, 29, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 29, 29, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 29, 29, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 29, 29, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 29, 29, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 29, 29, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 29, 29, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 29, 29, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 29, 29, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 29, 29, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 29, 29, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 29, 29, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 29, 29, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 29, 29, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 29, 29, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 29, 29, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 29, 29, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 29, 29, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 29, 29, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 29, 29, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 29, 29, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 14, 14, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 14, 14, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 14, 14, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 14, 14, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 14, 14, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 14, 14, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 14, 14, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 14, 14, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 14, 14, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 14, 14, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 14, 14, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 14, 14, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 14, 14, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 14, 14, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 14, 14, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 14, 14, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 14, 14, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 14, 14, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 14, 14, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 14, 14, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 14, 14, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 14, 14, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 14, 14, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 14, 14, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 14, 14, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 14, 14, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 14, 14, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 14, 14, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 14, 14, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 14, 14, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 14, 14, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 14, 14, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 14, 14, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 14, 14, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 14, 14, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 14, 14, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 14, 14, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 14, 14, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 14, 14, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 14, 14, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 14, 14, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 14, 14, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 14, 14, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 14, 14, 32)           36864     ['conv3_block10_1_relu[0][0]']
# ...
#
#  conv5_block9_2_conv (Conv2  (None, 3, 3, 32)             36864     ['conv5_block9_1_relu[0][0]']
#  D)
#
#  conv5_block9_concat (Conca  (None, 3, 3, 800)            0         ['conv5_block8_concat[0][0]',
#  tenate)                                                             'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchN  (None, 3, 3, 800)            3200      ['conv5_block9_concat[0][0]']
#  ormalization)
#
#  conv5_block10_0_relu (Acti  (None, 3, 3, 800)            0         ['conv5_block10_0_bn[0][0]']
#  vation)
#
#  conv5_block10_1_conv (Conv  (None, 3, 3, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 3, 3, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 3, 3, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 3, 3, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 3, 3, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 3, 3, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 3, 3, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 3, 3, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 3, 3, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 3, 3, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 3, 3, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 3, 3, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 3, 3, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 3, 3, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 3, 3, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 3, 3, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 3, 3, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 3, 3, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 3, 3, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 3, 3, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 3, 3, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 3, 3, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 3, 3, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 3, 3, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 3, 3, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 3, 3, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 3, 3, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 3, 3, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 3, 3, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 3, 3, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 3, 3, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 3, 3, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 3, 3, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 3, 3, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 3, 3, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 3, 3, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 3, 3, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 3, 3, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 3, 3, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 3, 3, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 3, 3, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 3, 3, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 3, 3, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 3, 3, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 3, 3, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 3, 3, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 3, 3, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 3, 3, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 3, 3, 1024)           0         ['bn[0][0]']
#
# ==================================================================================================
# Total params: 7037504 (26.85 MB)
# Trainable params: 6953856 (26.53 MB)
# Non-trainable params: 83648 (326.75 KB)
# __________________________________________________________________________________________________

# %%
# Compiling the model - Adam Optimizer
new_model2.compile(loss = "categorical_crossentropy", optimizer = optimizers.Adam(lr=0.00001), metrics=["accuracy"])
es = keras.callbacks.EarlyStopping(monitor='val_acc', verbose=1, mode='max', patience=2)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
#Fitting the model on the train data and labels.
batch_size = 100
history = new_model2.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), epochs=5, validation_data = (X_test, y_test), verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size, callbacks=[es])
print("Batch Size: 20, Epoch: 5, Optimizer: Adam")
show_confusion_matrix(history,new_model2, X_test, y_test)
# Out:
# <ipython-input-16-591a47d9e383>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = new_model2.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), epochs=5, validation_data = (X_test, y_test), verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size, callbacks=[es])
# Epoch 1/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 180s 30s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 179s 30s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 179s 31s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 182s 30s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/5
# 6/6 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 6/6 [==============================] - 176s 30s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Batch Size: 20, Epoch: 5, Optimizer: Adam
# 10/10 [==============================] - 16s 2s/step
# Confusion Matrix :
#
# [[294]]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
